# %%
import sys
sys.path.append("..")

from utils import pipeline, pipeline_2

# %%
pipeline('./init_MPI_strong.csv',
         mode='w',
         xaxis='size',
         yaxis='time',
         categories=['k'],
         speedup=True,
         efficiency=True,
         title='Strong MPI Scaling',
         save = False,
         save_path='./MPI_Strong_initw',   
)
# Out:
#    mode  size  nthreads      k      time  time_std
# 0     i     1        16  10000  0.633797  0.002753
# 2     i     2        16  10000  0.316021  0.001449
# 4     i     4        16  10000  0.162451  0.004882
# 6     i     8        16  10000  0.080440  0.003309
# 8     i    10        16  10000  0.063395  0.000528
# 10    i    12        16  10000  0.052831  0.000728
# 12    i    14        16  10000  0.046127  0.001041
# 14    i    16        16  10000  0.053511  0.008824
#    mode  size  nthreads      k      time  time_std
# 1     i     1        16  20000  2.522726  0.004463
# 3     i     2        16  20000  1.261433  0.001549
# 5     i     4        16  20000  0.630517  0.001825
# 7     i     8        16  20000  0.317172  0.003454
# 9     i    10        16  20000  0.253267  0.002948
# 11    i    12        16  20000  0.209609  0.000812
# 13    i    14        16  20000  0.181006  0.001692
# 15    i    16        16  20000  0.167621  0.004781
# ...

# %%
pipeline('./MPI_Weak_Init_Final.csv',
         mode='w',
         xaxis='size',
         yaxis='time',
         categories=None,
         speedup=True,
         efficiency=True,
         #ymin=100, ymax=250,
   
         title='Weak MPI Scaling',
         save = True,
         save_path='./MPI_Weak_initw',
     
)

# %%
pipeline('./init_OpenMP.csv',
         mode='i',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=True,
         efficiency=True,
         #ymin=100, ymax=250,
   
         title='Strong MPI Scaling',
         save = True,
         save_path='./MPI_Strong_initw',
     
)
