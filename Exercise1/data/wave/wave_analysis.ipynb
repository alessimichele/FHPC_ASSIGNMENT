# %%
import sys
sys.path.append("..")

from utils import pipeline, pipeline_2

# %% [markdown]
# # MPI strong scalability
#
# - --nodes=1
# - --ntasks-per-node=8
# - --cpus-per-task=16
# - MAPBY=numa
# - export OMP_PLACES=cores
# - export OMP_PROC_BIND=close
# - export OMP_NUM_THREADS=16

# %%
pipeline('MPI_Strong_Wave.csv',
         mode='r',
         xaxis='size',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=True,
         xtickssp=True,
         xtickseff=True,
         title='Strong MPI Scaling',
         save = True,
         save_path='./MPI_Strong_Wave',
         startidxeff=0,
)
# Out:
#    mode  size  nthreads     k        time  time_std
# 0     r     2        16  3000  148.030380  7.683405
# 2     r     3        16  3000  258.261706  4.142799
# 4     r     4        16  3000  338.957940  5.221639
# 6     r     5        16  3000  400.031116  9.954157
# 8     r     6        16  3000  498.207685  9.082160
# 10    r     7        16  3000  491.230182  8.165917
#    mode  size  nthreads     k         time    time_std
# 1     r     2        16  5000   802.966901    2.367164
# 3     r     3        16  5000  1078.107790   33.070049
# 5     r     4        16  5000  1493.647702   50.982176
# 7     r     5        16  5000  1936.523056   43.101574
# 9     r     6        16  5000  2287.703105   13.244097
# 11    r     7        16  5000  2094.159688  129.827227

# %%
pipeline('MPI_Strong_Wave.csv',
         mode='ig',
         xaxis='size',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=True,
         xtickssp=True,
         xtickseff=True,
         title='Inner Gather Bottleneck',
         save = True,
         save_path='./Bottleneck',
         startidxeff=0,
)
# Out:
#    mode  size  nthreads     k        time  time_std
# 0    ig     2        16  3000  109.366078  7.430213
# 2    ig     3        16  3000  218.403455  3.721691
# 4    ig     4        16  3000  300.723259  5.150917
# 6    ig     5        16  3000  361.702043  9.931053
# 8    ig     6        16  3000  458.637513  9.938512
# 10   ig     7        16  3000  452.143283  8.321185
#    mode  size  nthreads     k         time    time_std
# 1    ig     2        16  5000   691.656608    1.757998
# 3    ig     3        16  5000   967.384602   32.908803
# 5    ig     4        16  5000  1381.327232   49.845721
# 7    ig     5        16  5000  1824.861779   42.511555
# 9    ig     6        16  5000  2173.605356   13.303818
# 11   ig     7        16  5000  1981.046335  129.106642

# %%
pipeline('MPI_Strong_Wave.csv',
         mode='og',
         xaxis='size',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=True,
         xtickssp=True,
         xtickseff=True,
         title='Outer Gather Bottleneck',
         save = True,
         save_path='./OuterGatherBottleneck',
         startidxeff=0,
)
# Out:
#    mode  size  nthreads     k      time  time_std
# 0    og     2        16  3000  0.028172  0.000550
# 2    og     3        16  3000  0.060692  0.002372
# 4    og     4        16  3000  0.031882  0.001321
# 6    og     5        16  3000  0.090479  0.023144
# 8    og     6        16  3000  0.096643  0.010614
# 10   og     7        16  3000  0.227694  0.003591
# 12   og     8        16  3000  0.054608       NaN
#    mode  size  nthreads     k      time  time_std
# 1    og     2        16  5000  0.019900  0.007300
# 3    og     3        16  5000  0.018405  0.002957
# 5    og     4        16  5000  0.024490  0.000291
# 7    og     5        16  5000  0.044655  0.002826
# 9    og     6        16  5000  0.065273  0.004857
# 11   og     7        16  5000  0.025803  0.000238

# %% [markdown]
# # OpenMP Scalability

# %% [markdown]
# Dire della roba della cache

# %% [markdown]
# ### (tipo random nel socket)
#
# - --nodes=1
# - --ntasks-per-node=1
# - --cpus-per-task=64
# - MAPBY=socket
# - export OMP_PLACES=sockets
# - export OMP_PROC_BIND=false

# %%
pipeline('OpenMP_Wave_s_sf.csv',
         mode='r',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=[1]+[i for i in range(32,129,16)],
         xtickssp=[1]+[i for i in range(32,129,16)],
         xtickseff=[1]+[i for i in range(32,129,16)],
         startidxeff=0,
         yminsp=0,ymaxsp=8,
         title='OpenMP Scaling',
         save = True,
         save_path='./OpenMP_Wave_s_sf',
)
# Out:
#    mode  size  nthreads     k       time  time_std
# 0     r     1         1  3000  70.251874  0.140982
# 1     r     1         2  3000  53.250933  0.136447
# 2     r     1         4  3000  44.571864  0.149075
# 3     r     1         8  3000  40.577468  0.045736
# 4     r     1        16  3000  38.572606  0.101614
# 5     r     1        24  3000  37.978661  0.114482
# 6     r     1        32  3000  37.784839  0.076419
# 7     r     1        40  3000  37.642666  0.118618
# 8     r     1        48  3000  37.644148  0.146599
# 9     r     1        56  3000  37.930246  0.175548
# 10    r     1        64  3000  40.308499  1.556938
# 11    r     1        72  3000  65.341129  0.667926
# 12    r     1        80  3000  68.565324  0.564558
# 13    r     1        88  3000  72.259909  0.329972
# 14    r     1        96  3000  74.653671  0.543833
# 15    r     1       104  3000  77.944755  0.170746
# 16    r     1       112  3000  80.645223  0.543155
# ...

# %% [markdown]
# ###
#
# - --nodes=1
# - --ntasks-per-node=1
# - --cpus-per-task=128
# - MAPBY=node
# - export OMP_PLACES=cores
# - export OMP_PROC_BIND=close

# %%
pipeline('OpenMP_Wave_n_cc.csv',
         mode='r',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=[1]+[i for i in range(16,193,16)],
         xtickssp=True,
         xtickseff=True,
         startidxeff=0,
         title='OpenMP Scaling',
         save = True,
         save_path='./OpenMP_Wave_n_cc',
)
# Out:
#    mode  size  nthreads     k        time  time_std
# 0     r     1         1  3000   69.814112  0.020673
# 1     r     1         2  3000   71.959181  0.099011
# 2     r     1         4  3000   76.232482  0.029305
# 3     r     1         8  3000   84.393451  0.199654
# 4     r     1        16  3000  100.867178  0.210753
# 5     r     1        32  3000  133.471353  0.111692
# 6     r     1        48  3000  166.682359  0.065632
# 7     r     1        64  3000  200.357326  0.446974
# 8     r     1        80  3000  233.985283  0.979245
# 9     r     1        96  3000  266.942531  1.346968
# 10    r     1       112  3000  300.304863  0.156631
# 11    r     1       128  3000  333.673885  0.253508
# 12    r     1       144  3000  368.345408  0.306618
# 13    r     1       160  3000  403.128976  1.658058
# 14    r     1       176  3000  435.882836  1.227076
# 15    r     1       192  3000  469.350289       NaN

# %% [markdown]
# ###
#
# - --nodes=1
# - --ntasks-per-node=1
# - --cpus-per-task=64
# - MAPBY=socket
# - export OMP_PLACES=threads
# - export OMP_PROC_BIND=close

# %%
pipeline('OpenMP_Wave_s_tc.csv',
         mode='r',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=True,
         efficiency=True,
         xticks=[1,16]+[i for i in range(32,129,16)],
         xtickssp=True,
         xtickseff=True,
         startidxeff=0,
         title='OpenMP Scaling',
         save = True,
         save_path='./OpenMP_Wave_s_tc',
)
# Out:
#    mode  size  nthreads     k       time  time_std
# 0     r     1         1  3000  69.522584  0.194263
# 1     r     1         2  3000  52.887815  0.237221
# 2     r     1         4  3000  44.601850  0.824823
# 3     r     1         8  3000  40.089235  0.032959
# 4     r     1        16  3000  37.807466  0.115729
# 5     r     1        24  3000  37.342667  0.192946
# 6     r     1        32  3000  37.244615  0.004096
# 7     r     1        40  3000  37.565524  0.125461
# 8     r     1        48  3000  37.529811  0.120005
# 9     r     1        56  3000  37.902707  0.096179
# 10    r     1        64  3000  38.190114  0.116568
# 11    r     1        72  3000  66.331646  0.198111
# 12    r     1        80  3000  68.817527  0.663302
# 13    r     1        88  3000  70.928748  0.441822
# 14    r     1        96  3000  74.264207  0.315726
# 15    r     1       104  3000  77.542249  0.762536
# 16    r     1       112  3000  79.878537  1.067014
# ...

# %% [markdown]
# ###
#
# - --nodes=1
# - --ntasks-per-node=1
# - --cpus-per-task=64
# - MAPBY=socket
# - export OMP_PLACES=cores
# - export OMP_PROC_BIND=master

# %%
pipeline('OpenMP_Wave_s_cm.csv',
         mode='r',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=True,
         xtickssp=True,
         xtickseff=True,
         startidxeff=0,
         title='OpenMP Scaling',
         save = True,
         save_path='./OpenMP_Wave_s_cm',
)
# Out:
#   mode  size  nthreads     k         time  time_std
# 0    r     1         1  3000    71.451782  0.398750
# 1    r     1         2  3000  2748.548963  0.036886

# %% [markdown]
# ###
#
# - --nodes=1
# - --ntasks-per-node=1
# - --cpus-per-task=64
# - MAPBY=socket
# - export OMP_PLACES=cores
# - export OMP_PROC_BIND=spread

# %%
pipeline('OpenMP_Wave_s_cs.csv',
         mode='r',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=[1,4]+[i for i in range(8,65,8)],
         xtickssp=True,
         xtickseff=True,
         startidxeff=0,
         title='OpenMP Scaling',
         save = True,
         save_path='./OpenMP_Wave_s_cs',
)
# Out:
#    mode  size  nthreads     k       time  time_std
# 0     r     1         1  3000  69.672540  0.293573
# 1     r     1         2  3000  53.383402  0.185282
# 2     r     1         4  3000  45.029672  0.123598
# 3     r     1         8  3000  40.450315  0.063474
# 4     r     1        16  3000  38.670762  0.046440
# 5     r     1        24  3000  38.022809  0.024852
# 6     r     1        32  3000  37.886243  0.114517
# 7     r     1        40  3000  37.848139  0.074265
# 8     r     1        48  3000  37.818571  0.069783
# 9     r     1        56  3000  37.984442  0.162257
# 10    r     1        64  3000  38.182602  0.020519

# %% [markdown]
# ###
#
# - --nodes=1
# - --ntasks-per-node=1
# - --cpus-per-task=128
# - MAPBY=node
# - export OMP_PLACES=sockets
# - export OMP_PROC_BIND=spread

# %%
pipeline('OpenMP_Wave_n_ss.csv',
         mode='r',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=False,
         efficiency=False,
         xticks=[1,8]+[i for i in range(16,129,16)],
         xtickssp=True,
         xtickseff=True,
         startidxeff=0,
         title='OpenMP Scaling',
         save = True,
         save_path='./OpenMP_Wave_n_ss',
)
# Out:
#    mode  size  nthreads     k        time  time_std
# 0     r     1         1  3000   69.252496  0.690629
# 1     r     1         2  3000   72.039094  0.778312
# 2     r     1         4  3000   76.181879  0.796405
# 3     r     1         8  3000   85.202173  1.641847
# 4     r     1        16  3000  101.679618  0.124293
# 5     r     1        24  3000  119.073971  0.182819
# 6     r     1        32  3000  136.448792  0.671913
# 7     r     1        40  3000  153.462228  0.497754
# 8     r     1        48  3000  171.185817  0.489914
# 9     r     1        56  3000  188.743810  0.280682
# 10    r     1        64  3000  206.246897  0.260545
# 11    r     1        80  3000  240.600536  0.437333
# 12    r     1        96  3000  275.657513  0.584465
# 13    r     1       112  3000  310.799773  1.036999
# 14    r     1       128  3000  346.793123       NaN

# %% [markdown]
# ###
#
# - --nodes=1
# - --ntasks-per-node=1
# - --cpus-per-task=64
# - MAPBY=socket
# - export OMP_PLACES=cores
# - export OMP_PROC_BIND=close

# %%
pipeline('OpenMP_Wave_s_cc.csv',
         mode='r',
         xaxis='nthreads',
         yaxis='time',
         categories=['k'],
         speedup=True,
         efficiency=True,
         xticks=[1,4]+[i for i in range(8,65,8)],
         xtickssp=True,
         xtickseff=True,
         startidxeff=0,
         title='OpenMP Scaling',
         save = True,
         save_path='./OpenMP_Wave_s_cc',
)
# Out:
#    mode  size  nthreads     k       time  time_std
# 0     r     1         1  3000  70.648146  0.568623
# 1     r     1         2  3000  52.218752  0.022612
# 2     r     1         4  3000  43.757586  0.112004
# 3     r     1         8  3000  39.880114  0.089441
# 4     r     1        16  3000  37.853117  0.122371
# 5     r     1        24  3000  37.375141  0.118232
# 6     r     1        32  3000  37.547678  0.329149
# 7     r     1        40  3000  37.452394  0.048323
# 8     r     1        48  3000  37.663603  0.123639
# 9     r     1        56  3000  37.893328  0.059548
# 10    r     1        64  3000  38.310318  0.118759
